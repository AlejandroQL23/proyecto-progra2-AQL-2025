# %%
from Premier_League.src.cargaDatos.cargador_datos import CargadorDatos
from Premier_League.src.visualizacion.visualizador import Visualizador

# %%
cargador = CargadorDatos(ruta_base="../src/data/processed")
df = cargador.cargar_csv("premier_clean.csv")
# Out:
# Iniciando carga de: premier_clean.csv
# ...
# PROYECTO PROGRAMACION 2: INFORMACION ARCHIVO CARGADO
# ...
# Archivo: premier_clean.csv
# Número de filas: 4,218
# Número de columnas: 26
# Porcentaje global de nulos: 0.00%
# ------------------------------------------------------------
# Primeras 5 filas:
#                Player               Team Nation Position  Age  Minutes  Goals  \
# 0     Bruno Fernandes  Manchester United    POR       FW   29     90.0      0
# 1     Marcus Rashford  Manchester United    ENG       LW   26     90.0      0
# 2  Alejandro Garnacho  Manchester United    ARG       RW   20     30.0      0
# 3         Mason Mount  Manchester United    ENG       AM   25     60.0      0
# 4      Joshua Zirkzee  Manchester United    NED       FW   23     30.0      1
#
#    Assists  Total Shoot  Shoot on Target  ...  Expected Assists (xAG)  \
# 0        0            6                3  ...                     0.0
# 1        0            0                0  ...                     0.7
# ...

# %% [markdown]
# | Posición (Español)            | Nombre en Inglés               | Abreviatura |
# |-------------------------------|--------------------------------|--------------|
# | Portero                       | Goalkeeper                     | **GK** |
# | Defensa central               | Centre Back                    | **CB** |
# | Defensa derecho               | Right Back                     | **RB** |
# | Defensa izquierdo             | Left Back                      | **LB** |
# | Lateral derecho (carrilero)   | Right Wing Back                | **RWB** |
# | Lateral izquierdo (carrilero) | Left Wing Back                 | **LWB** |
# | Líbero / defensa libre        | Sweeper                        | **SW** |
# | Mediocentro defensivo         | Defensive Midfielder            | **CDM** |
# | Mediocentro                   | Central Midfielder              | **CM** |
# | Mediocentro ofensivo          | Attacking Midfielder            | **CAM** |
# | Interior derecho              | Right Midfielder                | **RM** |
# | Interior izquierdo            | Left Midfielder                 | **LM** |
# | Extremo derecho               | Right Winger                    | **RW** |
# | Extremo izquierdo             | Left Winger                     | **LW** |
# | Segundo delantero / mediapunta| Second Striker / Supporting Striker | **SS** |
# | Delantero centro              | Striker / Centre Forward         | **ST** |
# | Delantero (general)           | Forward                          | **FW** |
# | Pivote                        | Holding Midfielder / Anchor      | **HM** |
# | Volante                       | Midfielder                       | **MF** |

# %% [markdown]
# # Guía de contrataciones local

# %%
vis= Visualizador(df)
equipo="Crystal Palace"
pos="RW"

# %% [markdown]
# # General

# %%
vis.grafico_pases_completados_tiempo(equipo=equipo)

# %%
vis.grafico_pases_completados_vs_progresivos(equipo=equipo)

# %%
vis.grafico_carries_vs_progresivos(equipo=equipo)

# %%
vis.acciones_creativas(equipo=equipo)

# %% [markdown]
# # Rojas y Amarillas

# %%
vis.disciplina(equipo=equipo, pos=pos)

# %% [markdown]
# # Sección Delantera y Mediocampo

# %%
vis.goles_vs_asistencias(equipo=equipo)

# %%
vis.xg_vs_goles(equipo=equipo)

# %% [markdown]
# # Sección Defensas

# %%
vis.precision_pases(equipo=equipo, pos="CB")

# %%
vis.defensiva_jugadores(equipo=equipo, pos="CB")

# %% [markdown]
# # Goleadores por país

# %%
vis.goles_por_pais(pais="arg")
